# %%
import numpy as np
import pandas as pd
from glob import glob
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from bm_functions import collect_correlation_results, collect_metadata

# %%
filepath = '/mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune'
adpaths = glob(filepath + '/*/*.h5ad')

meta_df = collect_metadata(adpaths)

method_suffix = {'chrysalis': 'chrysalis_', 'STAGATE': 'stagate_', 'GraphST': 'graphst_', 'MEFISTO': 'mefisto_', 'NSF': 'nsf_'}
method_df = pd.DataFrame()
method_df_mean = pd.DataFrame()
for name, suffix in method_suffix.items():
    csvs = glob(filepath + f'/*/{suffix}pearson.csv')
    df = collect_correlation_results(csvs, enforce_symmetry=False)

    df_melted = df.melt(var_name='index', value_name='correlation')
    df_melted = df_melted.merge(meta_df, left_on='index', right_index=True, how='left')
    df_melted = df_melted.dropna()

    # for col in df_melted.columns:
    #     if len(df_melted[col].unique()) == 1:
    #         df_melted.drop(col,inplace=True,axis=1)

    df_melted['method'] = name
    method_df = pd.concat([method_df, df_melted], axis=0, ignore_index=True)

    mean_corr_df = pd.DataFrame(df.mean()).T
    mean_df_melted = mean_corr_df.melt(var_name='hash', value_name='correlation')
    mean_df_melted['index'] = mean_df_melted.index
    mean_df_melted = mean_df_melted.drop(columns=['hash'])
    mean_df_melted = mean_df_melted.merge(meta_df, left_on='index', right_index=True, how='left')

    mean_df_melted['method'] = name
    method_df_mean = pd.concat([method_df_mean, mean_df_melted], axis=0, ignore_index=True)

    df = df.rename(columns={k: v for k, v in zip(meta_df.index, meta_df['hash'])})
    mean_corr = df.mean(axis=0).sort_values(ascending=False)

    # add arial font
    from matplotlib import font_manager

    font_files = mpl.font_manager.findSystemFonts()
    for font_file in font_files:
        font_manager.fontManager.addfont(font_file)
    # print(font_manager.get_font_names())

    plt.rcParams['svg.fonttype'] = 'none'

    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['arial']

    fig, ax = plt.subplots(1, 1, figsize=(10, 4))
    sns.barplot(df, ax=ax, color='#57CBAD', order=mean_corr.index)
    sns.stripplot(df, ax=ax, size=6, color=".3", order=mean_corr.index)
    ax.grid(axis='y', linestyle='-', linewidth='0.5', color='grey')
    ax.set_axisbelow(True)
    ax.set_ylabel("Pearson's r")
    ax.set_xlabel(None)
    # ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

    for label in ax.get_xticklabels():
        label.set_rotation(90)
        label.set_verticalalignment('top')
        label.set_horizontalalignment('right')
        # label.set_y(1.02)  # Adjust this value to set a fixed y position for all labels

    ax.set_ylim((0, 1))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.title(name)
    plt.tight_layout()
    plt.show()
# Out:
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/0315dac2b4ae/0315dac2b4ae_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/09f38c1da700/09f38c1da700_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/0ae757710434/0ae757710434_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/0db98f0d9af7/0db98f0d9af7_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/10f1e861a080/10f1e861a080_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/1873b2061aee/1873b2061aee_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/1912f4e7293c/1912f4e7293c_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/21a4e65a43c9/21a4e65a43c9_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/25c322ca0b42/25c322ca0b42_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/280fdbceb706/280fdbceb706_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/2bd48eaa0328/2bd48eaa0328_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/2cda06c95393/2cda06c95393_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/30bf1ba27fca/30bf1ba27fca_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/374d31540d21/374d31540d21_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/404136d67173/404136d67173_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/440c57c5a400/440c57c5a400_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/451bd9fe5e22/451bd9fe5e22_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/4b0f5f61c2c7/4b0f5f61c2c7_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/4ece7212fea4/4ece7212fea4_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/5f0fa38f3477/5f0fa38f3477_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/69385e46653e/69385e46653e_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/6a08dedf0e52/6a08dedf0e52_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/6e585252a749/6e585252a749_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/6f108a558133/6f108a558133_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/7154f1d59d54/7154f1d59d54_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/72a53ab24f1c/72a53ab24f1c_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/766258a719e6/766258a719e6_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/7837a04c7518/7837a04c7518_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/7a2d91bbfaef/7a2d91bbfaef_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/7bd61b8a1010/7bd61b8a1010_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/8416af34aac7/8416af34aac7_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/84c29ab5b8b6/84c29ab5b8b6_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/8d1ae11b010e/8d1ae11b010e_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/8d6412753524/8d6412753524_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/8e3d5b045637/8e3d5b045637_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/8ec8b3c79eb1/8ec8b3c79eb1_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/8ef14ce6d0a3/8ef14ce6d0a3_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/8fa772091449/8fa772091449_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/98591b4cef52/98591b4cef52_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/9a608c5c265c/9a608c5c265c_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/9b7f9b96da86/9b7f9b96da86_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/9b83f134732d/9b83f134732d_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/9ea7037fd40c/9ea7037fd40c_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/a05ef44a351b/a05ef44a351b_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/a45923979c7e/a45923979c7e_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/a62bc92ca98c/a62bc92ca98c_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/ac60eaa207ac/ac60eaa207ac_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/ae2687f871fb/ae2687f871fb_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/ae4803c1f963/ae4803c1f963_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/b0b19821f644/b0b19821f644_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/b65e3087321c/b65e3087321c_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/b7e46bbf7db9/b7e46bbf7db9_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/b969c89eafef/b969c89eafef_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/bb9f958ac4f0/bb9f958ac4f0_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/bc45405661ca/bc45405661ca_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/c04eef5a210f/c04eef5a210f_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/c1f7d01e3d0a/c1f7d01e3d0a_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/c32b41504af8/c32b41504af8_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/c5b5b41ecaa5/c5b5b41ecaa5_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/c5d750f0e3da/c5d750f0e3da_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/ca3bad630746/ca3bad630746_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/cb122d4d759a/cb122d4d759a_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/cde0831a6a4a/cde0831a6a4a_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/e16baaef700f/e16baaef700f_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/e1926bd70e77/e1926bd70e77_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/e1f5cccca78d/e1f5cccca78d_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/e2cdcfe14e75/e2cdcfe14e75_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/e3af95d3bdec/e3af95d3bdec_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/f0cd6454a4f7/f0cd6454a4f7_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/f20ac3acae1f/f20ac3acae1f_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/f38cca9a5cbd/f38cca9a5cbd_sth_adata.h5ad
# /mnt/f/chrysalis/chrysalis_supplementary_data/I_synthetic_data/tabula_sapiens_immune/ff569f14f3ae/ff569f14f3ae_sth_adata.h5ad

# %%
color_dict = {
    'chrysalis': '#91db57',
    'NSF': '#57d3db',
    'STAGATE': '#5770db',
    'MEFISTO': '#dbc257',
    'SpatialPCA': '#a157db',
    'GraphST': '#db7c57',
}

overall_mean = {}
for m in np.unique(method_df_mean['method']):
    v = method_df_mean.loc[method_df_mean['method'] == m, 'correlation'].mean()
    overall_mean[m] = v
overall_mean = pd.Series(overall_mean).sort_values(ascending=False)

import matplotlib.font_manager as fm

arial_font_path = '/mnt/c/Bern/fonts/arial.ttf'
font_prop = fm.FontProperties(fname=arial_font_path)
plt.rcParams['font.family'] = font_prop.get_name()
plt.rcParams['svg.fonttype'] = 'none'

fig, ax = plt.subplots(1, 1, figsize=(2.5, 4))
# sns.boxplot(method_df_mean, x='method', y='correlation', ax=ax)
sns.boxplot(method_df_mean, x='method', y='correlation', palette=color_dict, showfliers=False,
            boxprops={'edgecolor': "0.2"}, medianprops={"color": "0.2", 'alpha': 0.5},
            showmeans=True, meanprops={'marker': 'o', 'markerfacecolor': 'black', 'markeredgecolor': 'black'},
            order=overall_mean.index)
sns.stripplot(method_df_mean, x='method', y='correlation', ax=ax, size=3, color=".3", alpha=0.5,
              order=overall_mean.index)
ax.grid(axis='y', linestyle='-', linewidth='0.5', color='grey')
ax.set_axisbelow(True)
ax.set_ylabel("Pearson's r")
ax.set_xlabel(None)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.title('Synthetic data\nperformance')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6005/3826438195.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(method_df_mean, x='method', y='correlation', palette=color_dict, showfliers=False,
# /tmp/ipykernel_6005/3826438195.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
